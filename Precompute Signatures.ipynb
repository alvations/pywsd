# %%
import sys
import time

import pandas as pd
from tqdm import tqdm

from wn import WordNet

from pywsd.utils import lemmatize
from pywsd.lesk import synset_signatures

wn = WordNet()
# Out:
# Warming up PyWSD (takes ~10 secs)... took 7.674057960510254 secs.

# %%
all_signatures = []

start = time.time()
for ss in tqdm(wn.all_synsets()):
    ss_signature = {}
    offset = ss.offset()
    pos = ss.pos()
    idx = str(offset).zfill(8) + '-' + pos
    
    ss_signature['simple'] = synset_signatures(ss, hyperhypo=True, adapted=False,
                                               remove_stopwords=True, 
                                               to_lemmatize=True, remove_numbers=True,
                                               lowercase=True)
    
    ss_signature['adapted'] = synset_signatures(ss, hyperhypo=True, adapted=True,
                                                   remove_stopwords=True, 
                                                   to_lemmatize=True, remove_numbers=True,
                                                   lowercase=True)
    
    ss_signature['original'] = synset_signatures(ss, original_lesk=True,
                                                 remove_stopwords=True, 
                                                 to_lemmatize=True, remove_numbers=True,
                                                 lowercase=True)
    
    
    all_signatures.append({'name': ss.name(), 'offset-pos': idx, 
                           'original': ss_signature['original'], 
                           'simple': ss_signature['simple'], 
                           'adapted':ss_signature['adapted']})

print('took {}'.format(time.time() - start), file=sys.stderr)
# Out:
# 106966it [00:17, 5966.92it/s]
# took 18.12508487701416

# %%
df = pd.DataFrame(all_signatures)
df.head()
# Out:
#                                              adapted             name  \
# 0  {follow, buy, grant, skill, something, get, kn...        able.a.01
# 1  {fund, follow, skill, get, know-how, usually, ...      unable.a.01
# 2  {underside, stem, face, organism, away, axis, ...     abaxial.a.01
# 3  {upper, face, adaxial, organism, organ, axis, ...     adaxial.a.01
# 4             {face, acroscopic, toward, side, apex}  acroscopic.a.01
#
#    offset-pos                                           original  \
# 0  00001740-a  {do, ), skill, something, to, know-how, (, usu...
# 1  00002098-a  {), not, skill, to, know-how, (, usually, or, ...
# 2  00002312-a  {organism, away, axis, organ, or, from, facing...
# 3  00002527-a  {to, organism, organ, axis, or, facing, toward...
# 4  00002730-a          {on, or, facing, toward, side, apex, the}
#
#                                               simple
# 0  {follow, buy, grant, skill, something, get, kn...
# 1  {fund, follow, skill, get, know-how, usually, ...
# 2  {underside, stem, face, organism, away, axis, ...
# 3  {upper, face, adaxial, organism, organ, axis, ...
# 4             {face, acroscopic, toward, side, apex}

# %%
pywsd_signatures = df.set_index('name').T
pywsd_signatures.head()
# Out:
# name                                                able.a.01  \
# adapted     {follow, buy, grant, skill, something, get, kn...
# offset-pos                                         00001740-a
# original    {do, ), skill, something, to, know-how, (, usu...
# simple      {follow, buy, grant, skill, something, get, kn...
#
# name                                              unable.a.01  \
# adapted     {fund, follow, skill, get, know-how, usually, ...
# offset-pos                                         00002098-a
# original    {), not, skill, to, know-how, (, usually, or, ...
# simple      {fund, follow, skill, get, know-how, usually, ...
#
# name                                             abaxial.a.01  \
# adapted     {underside, stem, face, organism, away, axis, ...
# offset-pos                                         00002312-a
# original    {organism, away, axis, organ, or, from, facing...
# simple      {underside, stem, face, organism, away, axis, ...
#
# name                                             adaxial.a.01  \
# adapted     {upper, face, adaxial, organism, organ, axis, ...
# offset-pos                                         00002527-a
# original    {to, organism, organ, axis, or, facing, toward...
# simple      {upper, face, adaxial, organism, organ, axis, ...
#
# name                                  acroscopic.a.01  \
# adapted        {face, acroscopic, toward, side, apex}
# offset-pos                                 00002730-a
# original    {on, or, facing, toward, side, apex, the}
# simple         {face, acroscopic, toward, side, apex}
#
# name                                  basiscopic.a.01  \
# adapted        {face, toward, base, side, basiscopic}
# offset-pos                                 00002843-a
# original    {on, or, facing, toward, base, side, the}
# simple         {face, toward, base, side, basiscopic}
#
# name                                            abducent.a.01  \
# adapted     {adjacent, draw, part, abduct, away, especiall...
# offset-pos                                         00002956-a
# original    {adjacent, ;, part, especially, away, from, or...
# simple      {adjacent, draw, part, abduct, away, especiall...
#
# name                                            adducent.a.01  \
# adapted     {adjacent, draw, adduct, part, especially, tog...
# offset-pos                                         00003131-a
# original    {adjacent, drawing, ;, part, especially, or, m...
# simple      {adjacent, draw, adduct, part, especially, tog...
#
# name                                             nascent.a.01  \
# adapted     {parturient, born, emergent, emerge, begin, in...
# offset-pos                                         00003356-a
# original                         {being, beginning, or, born}
# simple              {born, begin, insurgency, nascent, chick}
#
# name                                               dying.a.01  \
# adapted     {civilization, process, life, man, die, wish, ...
# offset-pos                                         00003939-a
# original    {be, ceasing, process, life, in, to, from, pas...
# simple      {civilization, process, life, man, die, wish, ...
#
# name                              ...                          \
# adapted                           ...
# offset-pos                        ...
# original                          ...
# simple                            ...
#
# name                                            overcast.v.01  \
# adapted     {beach, cloud, darken, fall, weather, overcast...
# offset-pos                                         02770717-v
# original                         {make, overcast, cloudy, or}
# simple      {beach, cloud, darken, fall, weather, overcast...
#
# name                                           overcloud.v.01  \
# adapted     {sky, cloud, darken, overcloud, cloud_over, cl...
# offset-pos                                         02771020-v
# original                      {with, covered, clouds, become}
# simple      {sky, cloud, darken, overcloud, cloud_over, cl...
#
# name                                            clear_up.v.04  \
# adapted     {sky, clear, light_up, clear_up, storm, bright...
# offset-pos                                         02771169-v
# original                                      {clear, become}
# simple      {sky, clear, light_up, clear_up, storm, bright...
#
# name                                              blight.v.01  \
# adapted     {blight, much, plague, smite, may, suffer, aff...
# offset-pos                                         02771320-v
# original                       {blight, to, suffer, cause, a}
# simple      {blight, much, plague, smite, may, suffer, aff...
#
# name                                               swamp.v.01  \
# adapted     {flood, boat, drench, harbor, tsunami, every, ...
# offset-pos                                         02771564-v
# original      {submerged, be, or, drench, drenched, submerge}
# simple      {flood, boat, drench, harbor, tsunami, every, ...
#
# name                                             run_dry.v.01  \
# adapted     {summer, empty, water, run, run_dry, river, dr...
# offset-pos                                         02771756-v
# original                           {water, become, empty, of}
# simple      {summer, empty, water, run, run_dry, river, dr...
#
# name                                              fog_up.v.01  \
# adapted     {windshield, cloud, get, foggy, overcast, fog,...
# offset-pos                                         02771888-v
# original                                         {get, foggy}
# simple      {windshield, cloud, get, foggy, overcast, fog,...
#
# name                                                char.v.01  \
# adapted     {everything, forest, burn, combust, coal, dren...
# offset-pos                                         02771997-v
# original                                 {charcoal, to, burn}
# simple      {everything, forest, burn, combust, coal, dren...
#
# name                                                haze.v.01  \
# adapted     {cloud, overcast, cloudy, haze, hazy, dull, be...
# offset-pos                                         02772202-v
# original                  {cloudy, or, ,, hazy, dull, become}
# simple      {cloud, overcast, cloudy, haze, hazy, dull, be...
#
# name                                          deflagrate.v.01
# adapted     {great, must, burn, exercise, combust, deflagr...
# offset-pos                                         02772310-v
# original    {great, burn, to, and, intensity, cause, with,...
# simple      {great, must, burn, exercise, combust, deflagr...
#
# [4 rows x 106966 columns]

# %%
pywsd_signatures.to_pickle('signatures-wordnet-3.0.pkl',protocol=2)
