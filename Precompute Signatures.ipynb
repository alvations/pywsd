# %%
import sys
import time

import pandas as pd
from tqdm import tqdm

from wn import WordNet

from pywsd.utils import lemmatize
from pywsd.lesk import synset_signatures

wn = WordNet()
# Out:
# Warming up PyWSD (takes ~10 secs)... took 7.696908950805664 secs.

# %%
all_signatures = []

start = time.time()
for ss in tqdm(wn.all_synsets()):
    ss_signature = {}
    offset = ss.offset()
    pos = ss.pos()
    idx = str(offset).zfill(8) + '-' + pos
    
    ss_signature['simple'] = synset_signatures(ss, hyperhypo=True, adapted=False,
                                               remove_stopwords=True, 
                                               to_lemmatize=True, remove_numbers=True,
                                               lowercase=True)
    
    ss_signature['adapted'] = synset_signatures(ss, hyperhypo=True, adapted=True,
                                                   remove_stopwords=True, 
                                                   to_lemmatize=True, remove_numbers=True,
                                                   lowercase=True)
    
    ss_signature['original'] = synset_signatures(ss, original_lesk=True,
                                                 remove_stopwords=True, 
                                                 to_lemmatize=True, remove_numbers=True,
                                                 lowercase=True)
    
    
    all_signatures.append({'name': ss.name(), 'offset-pos': idx, 
                           'original': ss_signature['original'], 
                           'simple': ss_signature['simple'], 
                           'adapted':ss_signature['adapted']})

print('took {}'.format(time.time() - start), file=sys.stderr)
# Out:
# 106966it [00:23, 4483.62it/s]
# took 23.86339020729065

# %%
df = pd.DataFrame(all_signatures)
df.head()
# Out:
#                                              adapted             name  \
# 0  {skill, able, mean, usually, authority, grant,...        able.a.01
# 1  {skill, obtain, without, mean, usually, fund, ...      unable.a.01
# 2  {stem, underside, face, dorsal, organ, side, l...     abaxial.a.01
# 3  {toward, know, upper, face, organ, adaxial, si...     adaxial.a.01
# 4             {toward, acroscopic, apex, face, side}  acroscopic.a.01
#
#    offset-pos                                           original  \
# 0  00001740-a  {skill, followed, having, to, authority, ', us...
# 1  00002098-a  {skill, followed, having, to, usually, ', (, n...
# 2  00002312-a  {from, facing, of, or, organ, an, axis, away, ...
# 3  00002527-a  {toward, to, nearest, facing, of, or, organ, a...
# 4  00002730-a          {toward, apex, facing, or, side, on, the}
#
#                                               simple
# 0  {skill, able, mean, usually, authority, grant,...
# 1  {skill, obtain, without, mean, usually, fund, ...
# 2  {stem, underside, face, dorsal, organ, side, l...
# 3  {toward, know, upper, face, organ, adaxial, si...
# 4             {toward, acroscopic, apex, face, side}

# %%
pywsd_signatures = df.set_index('name').T
pywsd_signatures.head()
# Out:
# name                                                able.a.01  \
# adapted     {skill, able, mean, usually, authority, grant,...
# offset-pos                                         00001740-a
# original    {skill, followed, having, to, authority, ', us...
# simple      {skill, able, mean, usually, authority, grant,...
#
# name                                              unable.a.01  \
# adapted     {skill, obtain, without, mean, usually, fund, ...
# offset-pos                                         00002098-a
# original    {skill, followed, having, to, usually, ', (, n...
# simple      {skill, obtain, without, mean, usually, fund, ...
#
# name                                             abaxial.a.01  \
# adapted     {stem, underside, face, dorsal, organ, side, l...
# offset-pos                                         00002312-a
# original    {from, facing, of, or, organ, an, axis, away, ...
# simple      {stem, underside, face, dorsal, organ, side, l...
#
# name                                             adaxial.a.01  \
# adapted     {toward, know, upper, face, organ, adaxial, si...
# offset-pos                                         00002527-a
# original    {toward, to, nearest, facing, of, or, organ, a...
# simple      {toward, know, upper, face, organ, adaxial, si...
#
# name                                  acroscopic.a.01  \
# adapted        {toward, acroscopic, apex, face, side}
# offset-pos                                 00002730-a
# original    {toward, apex, facing, or, side, on, the}
# simple         {toward, acroscopic, apex, face, side}
#
# name                                  basiscopic.a.01  \
# adapted        {toward, basiscopic, face, side, base}
# offset-pos                                 00002843-a
# original    {toward, facing, base, or, side, on, the}
# simple         {toward, basiscopic, face, side, base}
#
# name                                            abducent.a.01  \
# adapted     {muscle, abduct, draw, especially, part, abduc...
# offset-pos                                         00002956-a
# original    {from, especially, muscles, of, or, part, draw...
# simple      {muscle, abduct, draw, especially, part, abduc...
#
# name                                            adducent.a.01  \
# adapted     {toward, muscle, adduct, especially, draw, add...
# offset-pos                                         00003131-a
# original    {toward, especially, muscles, of, or, part, dr...
# simple      {toward, muscle, adduct, especially, draw, add...
#
# name                                             nascent.a.01  \
# adapted     {dissilient, emerge, begin, born, parturient, ...
# offset-pos                                         00003356-a
# original                         {being, or, beginning, born}
# simple              {begin, born, nascent, insurgency, chick}
#
# name                                               dying.a.01  \
# adapted     {fire, wish, associate, man, passing, moribund...
# offset-pos                                         00003939-a
# original    {with, from, in, to, ceasing, of, passing, or,...
# simple      {fire, wish, associate, man, passing, process,...
#
# name                              ...                          \
# adapted                           ...
# offset-pos                        ...
# original                          ...
# simple                            ...
#
# name                                            overcast.v.01  \
# adapted     {fall, haze, weather, often, cloudy, fog_up, o...
# offset-pos                                         02770717-v
# original                         {overcast, cloudy, or, make}
# simple      {fall, haze, weather, often, cloudy, fog_up, o...
#
# name                                           overcloud.v.01  \
# adapted     {overcloud, cloud_over, darken, become, cloud,...
# offset-pos                                         02771020-v
# original                      {covered, become, clouds, with}
# simple      {overcloud, cloud_over, darken, become, cloud,...
#
# name                                            clear_up.v.04  \
# adapted     {storm, brighten, clear, become, light_up, cle...
# offset-pos                                         02771169-v
# original                                      {become, clear}
# simple      {storm, brighten, clear, become, light_up, cle...
#
# name                                              blight.v.01  \
# adapted     {afflict, cause, blight, suffer, smite, plague...
# offset-pos                                         02771320-v
# original                       {to, cause, a, blight, suffer}
# simple      {afflict, cause, blight, suffer, smite, plague...
#
# name                                               swamp.v.01  \
# adapted     {tsunami, drench, every, submerge, swamp, boat...
# offset-pos                                         02771564-v
# original      {drench, or, drenched, submerge, submerged, be}
# simple      {tsunami, drench, every, submerge, swamp, boat...
#
# name                                             run_dry.v.01  \
# adapted     {dry_out, run, dry, river, run_dry, empty, bec...
# offset-pos                                         02771756-v
# original                           {empty, become, of, water}
# simple      {dry_out, run, dry, river, run_dry, empty, bec...
#
# name                                              fog_up.v.01  \
# adapted     {fog, get, windshield, fog_up, foggy, cloud, o...
# offset-pos                                         02771888-v
# original                                         {foggy, get}
# simple      {fog, get, windshield, fog_up, foggy, cloud, o...
#
# name                                                char.v.01  \
# adapted     {without, fire, drench, char, charcoal, everyt...
# offset-pos                                         02771997-v
# original                                 {charcoal, to, burn}
# simple      {without, fire, drench, char, charcoal, everyt...
#
# name                                                haze.v.01  \
# adapted     {haze, dull, cloudy, become, cloud, overcast, ...
# offset-pos                                         02772202-v
# original                  {,, or, dull, cloudy, become, hazy}
# simple      {haze, dull, cloudy, become, cloud, overcast, ...
#
# name                                          deflagrate.v.01
# adapted     {must, care, cause, rapidly, deflagrate, inten...
# offset-pos                                         02772310-v
# original    {with, to, cause, rapidly, intensity, and, bur...
# simple      {must, care, cause, rapidly, deflagrate, inten...
#
# [4 rows x 106966 columns]

# %%
pywsd_signatures.to_pickle('signatures-wordnet-3.0.pkl',protocol=2)
